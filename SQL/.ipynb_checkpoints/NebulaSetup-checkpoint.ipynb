# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy import text
import requests

# %%
courses = pd.DataFrame(columns=["ID", "Title", "course_prefix", "class_number", "Sections"])
courses
# Out:
# Empty DataFrame
# Columns: [ID, Title, course_prefix, class_number, Sections]
# Index: []

# %%
r = requests.get("https://api.utdnebula.com/course?offset=0", headers={"x-api-key": "AIzaSyCSKtOmawF-XMVL7AtYuIAOGt7b-eyCbOI"})
offset = 0
counter = 0
while r.json()["data"] != None:
    offset += 20
    counter += 1
    for course in r.json()["data"]:
        temp_df2 = pd.DataFrame(data = {"ID": course["_id"], "Title": course["title"], "course_prefix": course["subject_prefix"], "class_number": course["course_number"], "Sections": course["sections"]})
        courses = pd.concat([courses, temp_df2], ignore_index=True)
    r = requests.get(f"https://api.utdnebula.com/course?offset={offset}", headers={"x-api-key": "AIzaSyCSKtOmawF-XMVL7AtYuIAOGt7b-eyCbOI"})
print(counter)
# Out:
# 908

# %%
courses.drop_duplicates(subset="Sections")
# Out:
#                              ID  \
# 0      65d2e07add0e07205b0e0bb8
# 1      65d2e07add0e07205b0e0bb8
# 2      65d2e07add0e07205b0e0bb8
# 3      65d2e07add0e07205b0e0bb8
# 4      65d2e07add0e07205b0e0bb8
# ...                         ...
# 62517  65d2e0eddd0e07205b0ea4eb
# 62518  65d2e134dd0e07205b0efcc3
# 62519  65d2e134dd0e07205b0efcc1
# 62520  65d2e134dd0e07205b0efcc1
# 62521  65d2e111dd0e07205b0ed129
#
#                                                    Title course_prefix  \
# 0                      Introductory Financial Accounting          ACCT
# 1                      Introductory Financial Accounting          ACCT
# 2                      Introductory Financial Accounting          ACCT
# 3                      Introductory Financial Accounting          ACCT
# 4                      Introductory Financial Accounting          ACCT
# ...                                                  ...           ...
# 62517  Advanced Topics in Aesthetic Studies  - Darwin...          VPAS
# ...

# %%
sections = pd.DataFrame(columns=["ID", "instructor", "term", "section"])
sections
# Out:
# Empty DataFrame
# Columns: [ID, instructor, term, section]
# Index: []

# %%
r = requests.get("https://api.utdnebula.com/section?offset=0&academic_session.name=24S", headers={"x-api-key": "AIzaSyCSKtOmawF-XMVL7AtYuIAOGt7b-eyCbOI"})
r.json()["data"]
offset = 0
counter = 0
while r.json()["data"] != None:
    offset += 20
    counter += 1
    for section in r.json()["data"]:
        temp_df2 = pd.DataFrame(data = {"ID": section["_id"], "instructor": section["professors"], "term": section["academic_session"]["name"], "section": section["section_number"]})
        sections = pd.concat([sections, temp_df2], ignore_index=True)
    r = requests.get(f"https://api.utdnebula.com/section?offset={offset}&academic_session.name=24S", headers={"x-api-key": "AIzaSyCSKtOmawF-XMVL7AtYuIAOGt7b-eyCbOI"})
print(counter)
# Out:
# 192

# %%
sections = sections.drop_duplicates("ID")
sections
# Out:
#                             ID                instructor term section
# 0     65d2e168dd0e07205b0f3da1  6556ae2e9f9c0d3789210111  24S     001
# 1     65d2e16add0e07205b0f3fe5  6556ad5e9f9c0d378920ff85  24S     001
# 2     65d2e16edd0e07205b0f4448  6556ad289f9c0d378920ff20  24S     501
# 3     65d2e16cdd0e07205b0f41b3  65d2e14add0e07205b0f17ca  24S     001
# 4     65d2e174dd0e07205b0f4b0a  6556adb39f9c0d378921002e  24S     0W1
# ...                        ...                       ...  ...     ...
# 3701  65d2e170dd0e07205b0f463c  65d2e082dd0e07205b0e189e  24S     0W1
# 3702  65d2e173dd0e07205b0f498c  6556ae4d9f9c0d3789210152  24S     0W2
# 3703  65d2e174dd0e07205b0f4a7a  6556ad629f9c0d378920ff8e  24S     001
# 3704  65d2e172dd0e07205b0f486e  6556ac1d9f9c0d378920fd14  24S     001
# 3705  65d2e16edd0e07205b0f441c  65d2e149dd0e07205b0f1603  24S     001
#
# [3534 rows x 4 columns]

# %%
classes = sections.merge(courses, left_on="ID", right_on="Sections", how="inner")
classes = classes.drop(columns=["ID_x", "ID_y", "Sections"])
classes
# Out:
#                     instructor term section  \
# 0     6556ae2e9f9c0d3789210111  24S     001
# 1     6556ad5e9f9c0d378920ff85  24S     001
# 2     6556ad289f9c0d378920ff20  24S     501
# 3     65d2e14add0e07205b0f17ca  24S     001
# 4     6556adb39f9c0d378921002e  24S     0W1
# ...                        ...  ...     ...
# 3529  65d2e082dd0e07205b0e189e  24S     0W1
# 3530  6556ae4d9f9c0d3789210152  24S     0W2
# 3531  6556ad629f9c0d378920ff8e  24S     001
# 3532  6556ac1d9f9c0d378920fd14  24S     001
# 3533  65d2e149dd0e07205b0f1603  24S     001
#
#                                                   Title course_prefix  \
# 0                                  Networked Identities          ATCM
# 1                       Modeling for Business Analytics          BUAN
# 2                      Advanced Engineering Mathematics          ENGR
# 3                      Introduction to Criminal Justice          CRIM
# 4     Quality Improvement in Healthcare  Six Sigma a...          OPRE
# ...

# %%
professors = pd.DataFrame(columns=["ID", "first_name", "last_name"])
professors
# Out:
# Empty DataFrame
# Columns: [ID, first_name, last_name]
# Index: []

# %%
r = requests.get("https://api.utdnebula.com/professor?offset=0", headers={"x-api-key": "AIzaSyCSKtOmawF-XMVL7AtYuIAOGt7b-eyCbOI"})
r.json()["data"]
offset = 0
counter = 0
while r.json()["data"] != None:
    offset += 20
    counter += 1
    for professor in r.json()["data"]:
        temp_df2 = pd.DataFrame(data = {"ID": [professor["_id"]], "first_name": [professor["first_name"]], "last_name": [professor["last_name"]]})
        professors = pd.concat([professors, temp_df2], ignore_index=True)
    r = requests.get(f"https://api.utdnebula.com/professor?offset={offset}", headers={"x-api-key": "AIzaSyCSKtOmawF-XMVL7AtYuIAOGt7b-eyCbOI"})
print(counter)
# Out:
# 155

# %%
professors["instructors"] = professors.apply(lambda x: x[1] + " " + x[2], axis=1)
# Out:
# /tmp/ipykernel_411129/3551553407.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   professors["instructors"] = professors.apply(lambda x: x[1] + " " + x[2], axis=1)

# %%
professors = professors.drop(columns=["first_name", "last_name"])

# %%
classes = classes.merge(professors, left_on="instructor", right_on="ID", how="inner")
classes = classes.drop(columns=["instructor", "Title", "ID"])
classes

# %%
classes["instructor"] = classes["instructors"]
classes = classes.drop(columns="instructors")
classes
# Out:
#      term section course_prefix class_number         instructor
# 0     24S     001          ATCM         3321     Dora Valkanova
# 1     24S     001          BUAN         6383         Syam Menon
# 2     24S     501          ENGR         3300           Jung Lee
# 3     24S     001          CRIM         1301   Allison Escobedo
# 4     24S     0W1          OPRE         6354  Kannan Ramanathan
# ...   ...     ...           ...          ...                ...
# 3529  24S     0W1          HLTH         3101        Lona Sandon
# 3530  24S     0W2           MKT         3300            Fang Wu
# 3531  24S     001           NSC         4V90         Van Miller
# 3532  24S     001          MATH         6312     Carlos Arreche
# 3533  24S     001          EEMF         6321       Sourav Dutta
#
# [3534 rows x 5 columns]

# %%
to_delete = []
for i, num in enumerate(classes["class_number"]):
    if not num.isnumeric():
        to_delete.append(i)
classes = classes.drop(to_delete)

# %%
secrets_file = open("../back-end/.secrets", 'r')
conn_secret = secrets_file.readline()
conn_secret = conn_secret.strip()

# %%
engine = create_engine(conn_secret)

# %%
with engine.connect() as conn:
    # classes.to_sql(name="class", index=False, con=conn, if_exists="append")

# %%
# add all individual professors and courses
with engine.connect() as conn:
    classes = pd.read_sql_table('class', conn)

# %%
professors = pd.DataFrame(columns=classes.columns)
professors
# Out:
# Empty DataFrame
# Columns: [class_id, class_number, course_prefix, instructor, term, section]
# Index: []

# %%
len(set(classes["instructor"]))
# Out:
# 1221

# %%
for i in set(classes["instructor"]):
    professors.loc[len(professors)] = [None, None, None, i, None, None]

# %%
courses = classes

# %%
courses = courses.iloc[0:0]
courses = courses.drop(columns="class_id")
courses
# Out:
# Empty DataFrame
# Columns: [class_number, course_prefix, instructor, term, section]
# Index: []

# %%
professors = professors.drop(columns="class_id")

# %%
course_string = classes.apply(lambda x: f"{x[1]}" + " " + x[2], axis = 1)
# Out:
# /tmp/ipykernel_12893/1229141457.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   course_string = classes.apply(lambda x: f"{x[1]}" + " " + x[2], axis = 1)

# %%
for i in (set(course_string)):
    string = i.split()
    courses.loc[len(courses)] = [string[0], string[1], None, None, None]

# %%
courses
# Out:
#      class_number course_prefix instructor  term section
# 0            6327          HMGT       None  None    None
# 1            6333          SYSM       None  None    None
# 2            4381           NSC       None  None    None
# 3            4388          HIST       None  None    None
# 4            4306          HLTH       None  None    None
# ...           ...           ...        ...   ...     ...
# 1605         4360          BIOL       None  None    None
# 1606         4337           FIN       None  None    None
# 1607         6386           SOC       None  None    None
# 1608         4330          OPRE       None  None    None
# 1609         4337          ACCT       None  None    None
#
# [1610 rows x 5 columns]

# %%
courses
# Out:
# Empty DataFrame
# Columns: [class_number, course_prefix, instructor, term, section]
# Index: []

# %%
with engine.connect() as conn:
    courses.to_sql(name="class", index=False, con=conn, if_exists="append")

# %%
with engine.connect() as conn:
    professors.to_sql(name="class", index=False, con=conn, if_exists="append")
